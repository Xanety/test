# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

df=pd.read_csv ('Surgut-2\surgut_1.csv', sep=';', index_col=0, parse_dates=True,dayfirst=True)
df_subset = df.iloc[:10]
# Out:
# C:\Users\das\AppData\Local\Temp\ipykernel_10772\4268004211.py:5: DtypeWarning: Columns (22) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv ('Surgut-2\surgut_1.csv', sep=';', index_col=0, parse_dates=True,dayfirst=True)

# %%
# df.columns=['time','F','U1','P','Q','Uf','If','def_P_amp','def_P_ang','def_P_freq']
# df.head ()

# %%
plt.plot(df['СурГРЭС-2 ПЭ-Б-7, Fu1, Гц[RES3-45220/Fu1/none/none]']) #
plt.show()
